# %% [markdown]
# ## Importing Modules

# %%
import pandas as pd
import re

# %% [markdown]
# ## Setting the row and Column display to max

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Preprocessing of Each State Data

# %% [markdown]
# ### 1. Andhra Pradesh

# %%
data_AP = pd.read_excel('P2011-14.xls', sheet_name=0)

# %%
data_AP.head()
# Out:
#                                           Unnamed: 0     Unnamed: 1  \
# 0  ANDHRA PRADESH Mandal selection for the Block ...            NaN
# 1                                            Zone No  District Name
# 2                                            Zone -I     Srikakulam
# 3                                            Zone -I     Srikakulam
# 4                                            Zone -I  Vizianagaram.
#
#     Unnamed: 2     Unnamed: 3     Unnamed: 4
# 0          NaN            NaN            NaN
# 1  Tehsil Code    Tehsil Name   Village Name
# 2            1  Vajrapukothur  Patha Tekkali
# 3            2     Amdalavasa           Dusi
# 4            3     Bondapalli       B.Rajeru

# %%
data_AP = data_AP.iloc[1:].reset_index(drop=True)

data_AP.columns = data_AP.iloc[0]

data_AP = data_AP.drop(0).reset_index(drop=True)

data_AP['State Name'] = 'Andhra Pradesh'
data_AP['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_AP.head()
# Out:
# 0  Zone No  District Name Tehsil Code     Tehsil Name   Village Name  \
# 0  Zone -I     Srikakulam           1   Vajrapukothur  Patha Tekkali
# 1  Zone -I     Srikakulam           2      Amdalavasa           Dusi
# 2  Zone -I  Vizianagaram.           3      Bondapalli       B.Rajeru
# 3  Zone -I  Vishakapatnam           4  Makavara Palem      Byyavaram
# 4  Zone-II  East Godavari           5      Samalkota          J.Peta
#
# 0      State Name       Year
# 0  Andhra Pradesh  2011-2014
# 1  Andhra Pradesh  2011-2014
# 2  Andhra Pradesh  2011-2014
# 3  Andhra Pradesh  2011-2014
# 4  Andhra Pradesh  2011-2014

# %%
data_AP.head()
# Out:
# 0  Zone No  District Name Tehsil Code     Tehsil Name   Village Name  \
# 0  Zone -I     Srikakulam           1   Vajrapukothur  Patha Tekkali
# 1  Zone -I     Srikakulam           2      Amdalavasa           Dusi
# 2  Zone -I  Vizianagaram.           3      Bondapalli       B.Rajeru
# 3  Zone -I  Vishakapatnam           4  Makavara Palem      Byyavaram
# 4  Zone-II  East Godavari           5      Samalkota          J.Peta
#
# 0      State Name       Year
# 0  Andhra Pradesh  2011-2014
# 1  Andhra Pradesh  2011-2014
# 2  Andhra Pradesh  2011-2014
# 3  Andhra Pradesh  2011-2014
# 4  Andhra Pradesh  2011-2014

# %% [markdown]
# ### 2. Assam

# %%
data_Assam = pd.read_excel('P2011-14.xls', sheet_name=1)

# %%
data_Assam.head()
# Out:
#   Unnamed: 0      Unnamed: 1   Unnamed: 2       Unnamed: 3     Unnamed: 4
# 0    Zone No   District Name  Tehsil Code     Tehsil Name   Village Name
# 1          I         Dhemaji            1          Dhemaji      Ghilaguri
# 2        NaN             NaN          NaN              NaN       Gualgaon
# 3        NaN             NaN          NaN              NaN         Nagaon
# 4        NaN       Lakhimpur            2  North Lakhimpur       Hatilung

# %%
data_Assam.columns = data_Assam.iloc[0]

data_Assam = data_Assam.drop(0).reset_index(drop=True)

data_Assam['State Name'] = 'Assam'
data_Assam['Year'] = '2011-2014'

# %%
data_Assam = data_Assam.ffill()

# %%
data_Assam.head()
# Out:
# 0 Zone No  District Name  Tehsil Code     Tehsil Name  Village Name   \
# 0       I        Dhemaji            1          Dhemaji     Ghilaguri
# 1       I        Dhemaji            1          Dhemaji      Gualgaon
# 2       I        Dhemaji            1          Dhemaji        Nagaon
# 3       I      Lakhimpur            2  North Lakhimpur      Hatilung
# 4       I      Lakhimpur            2  North Lakhimpur     Bogalijan
#
# 0 State Name       Year
# 0      Assam  2011-2014
# 1      Assam  2011-2014
# 2      Assam  2011-2014
# 3      Assam  2011-2014
# 4      Assam  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']

data_Assam.columns = new_column_names

# %% [markdown]
# ### 3. Bihar

# %%
data_BH = pd.read_excel('P2011-14.xls', sheet_name=2)

# %%
data_BH.head()
# Out:
#   Districts and Tehsils of Bihar and Jharkhand for block period 2011-14  \
# 0                                              Bihar
# 1                                            Zone No
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#       Unnamed: 1   Unnamed: 2    Unnamed: 3           Unnamed: 4
# 0            NaN          NaN           NaN                  NaN
# 1  District Name  Tehsil Code  Tehsil Name          Village Name
# 2     Samastipur            1    Samastipur         Raghunathpur
# 3     Samastipur            2    Samastipur             Barbatta
# 4     Samastipur            3         Rosra  Thahara Baijnathpur

# %%
data_BH = data_BH.iloc[1:].reset_index(drop=True)

data_BH.columns = data_BH.iloc[0]

data_BH = data_BH.drop(0).reset_index(drop=True)

data_BH['State Name'] = 'Bihar'
data_BH['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_BH.head()
# Out:
# 0 Zone No District Name Tehsil Code Tehsil Name          Village Name  \
# 0       1    Samastipur           1   Samastipur         Raghunathpur
# 1       1    Samastipur           2   Samastipur             Barbatta
# 2       1    Samastipur           3        Rosra  Thahara Baijnathpur
# 3       1     Madhubani           4  Jhanjharpur                Behat
# 4       1     Madhubani           5     Jainagar          Dhaniapatti
#
# 0 State Name       Year
# 0      Bihar  2011-2014
# 1      Bihar  2011-2014
# 2      Bihar  2011-2014
# 3      Bihar  2011-2014
# 4      Bihar  2011-2014

# %%
data_BH = data_BH.iloc[:44]

# %%
data_BH.head()
# Out:
# 0 Zone No District Name Tehsil Code Tehsil Name          Village Name  \
# 0       1    Samastipur           1   Samastipur         Raghunathpur
# 1       1    Samastipur           2   Samastipur             Barbatta
# 2       1    Samastipur           3        Rosra  Thahara Baijnathpur
# 3       1     Madhubani           4  Jhanjharpur                Behat
# 4       1     Madhubani           5     Jainagar          Dhaniapatti
#
# 0 State Name       Year
# 0      Bihar  2011-2014
# 1      Bihar  2011-2014
# 2      Bihar  2011-2014
# 3      Bihar  2011-2014
# 4      Bihar  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']

data_BH.columns = new_column_names

# %% [markdown]
# ### 4. Jharkhand

# %%
data_JH = pd.read_excel('P2011-14.xls', sheet_name=2)

# %%
data_JH.head()
# Out:
#   Districts and Tehsils of Bihar and Jharkhand for block period 2011-14  \
# 0                                              Bihar
# 1                                            Zone No
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#       Unnamed: 1   Unnamed: 2    Unnamed: 3           Unnamed: 4
# 0            NaN          NaN           NaN                  NaN
# 1  District Name  Tehsil Code  Tehsil Name          Village Name
# 2     Samastipur            1    Samastipur         Raghunathpur
# 3     Samastipur            2    Samastipur             Barbatta
# 4     Samastipur            3         Rosra  Thahara Baijnathpur

# %%
data_JH = data_JH.iloc[47:]

# %%
data_JH.head()
# Out:
#    Districts and Tehsils of Bihar and Jharkhand for block period 2011-14  \
# 47                                                NaN
# 48                                          Jharkhand
# 49                                            Zone No
# 50                                                  1
# 51                                                  1
#
#        Unnamed: 1   Unnamed: 2    Unnamed: 3    Unnamed: 4
# 47            NaN          NaN           NaN           NaN
# 48            NaN          NaN           NaN           NaN
# 49  District Name  Tehsil Code  Tehsil Name   Village Name
# 50        Deoghar            1       Deoghar      Janakpur
# 51        Deoghar            2       Deoghar     Chakarana

# %%
data_JH = data_JH.iloc[2:].reset_index(drop=True)

data_JH.columns = data_JH.iloc[0]

data_JH = data_JH.drop(0).reset_index(drop=True)

data_JH['State Name'] = 'Jharkhand'
data_JH['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_JH.head()
# Out:
# 0 Zone No District Name Tehsil Code Tehsil Name  Village Name State Name  \
# 0       1       Deoghar           1      Deoghar     Janakpur  Jharkhand
# 1       1       Deoghar           2      Deoghar    Chakarana  Jharkhand
# 2       1         Dumka           3        Dumka    Pokhariya  Jharkhand
# 3       1       Jamtara           4      Jamtara    Udalbanni  Jharkhand
# 4       1     Hazaribag           5    Hazaribag   Mehashwara  Jharkhand
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']

data_JH.columns = new_column_names

# %% [markdown]
# ### 5. Gujarat

# %%
data_GJ = pd.read_excel('P2011-14.xls', sheet_name=3)

# %%
data_GJ.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN  Gujarat- List of Clusters for the Block Period...
# 1         NaN                                                NaN
# 2         NaN                                            Zone No
# 3         NaN                                                  1
# 4         NaN                                                  1
#
#       Unnamed: 2   Unnamed: 3   Unnamed: 4 Unnamed: 5
# 0            NaN          NaN          NaN        NaN
# 1            NaN          NaN          NaN        NaN
# 2  District Name  Tehsil Code  Tehsil Name    Village
# 3           Tapi            1      Songarh     Mandal
# 4           Tapi            2        Valod    Delwada

# %%
data_GJ = data_GJ.drop(data_GJ.columns[0], axis=1)

# %%
data_GJ.head()
# Out:
#                                           Unnamed: 1     Unnamed: 2  \
# 0  Gujarat- List of Clusters for the Block Period...            NaN
# 1                                                NaN            NaN
# 2                                            Zone No  District Name
# 3                                                  1           Tapi
# 4                                                  1           Tapi
#
#     Unnamed: 3   Unnamed: 4 Unnamed: 5
# 0          NaN          NaN        NaN
# 1          NaN          NaN        NaN
# 2  Tehsil Code  Tehsil Name    Village
# 3            1      Songarh     Mandal
# 4            2        Valod    Delwada

# %%
data_GJ = data_GJ.iloc[2:].reset_index(drop=True)

data_GJ.columns = data_GJ.iloc[0]

data_GJ = data_GJ.drop(0).reset_index(drop=True)

data_GJ['State Name'] = 'Gujarat'
data_GJ['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_GJ.head()
# Out:
# 0 Zone No District Name Tehsil Code Tehsil Name     Village State Name  \
# 0       1          Tapi           1     Songarh      Mandal    Gujarat
# 1       1          Tapi           2       Valod     Delwada    Gujarat
# 2       2       Narmada           3       Nadod       Rundh    Gujarat
# 3       2       Bharuch           4       Valia      Pathar    Gujarat
# 4       3      Vadodara           5    Sankheda  Gola Gamdi    Gujarat
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']

data_GJ.columns = new_column_names

# %% [markdown]
# ### 6. Himachal Pradesh

# %%
data_HP = pd.read_excel('P2011-14.xls', sheet_name=4)

# %%
data_HP.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN                         H.P. University, Shimla-5.
# 1         NaN                                                NaN
# 2         NaN  Sub :  Sampling for the crop complex year 2011...
# 3         NaN                                               Zone
# 4         NaN                                                NaN
#
#                                    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                         NaN        NaN        NaN
# 1  Sampling for the crop complex year 2011-14        NaN        NaN
# 2                                         NaN        NaN        NaN
# 3                               Tehsil (Nos.)     Tehsil   District
# 4                                           1     Chamba     Chamba
#
#         Unnamed: 5
# 0              NaN
# 1              NaN
# 2              NaN
# 3  Cluster Village
# 4           1.Nanu

# %%
data_HP = data_HP.drop(data_HP.columns[0], axis=1)

# %%
data_HP.head()
# Out:
#                                           Unnamed: 1  \
# 0                         H.P. University, Shimla-5.
# 1                                                NaN
# 2  Sub :  Sampling for the crop complex year 2011...
# 3                                               Zone
# 4                                                NaN
#
#                                    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                         NaN        NaN        NaN
# 1  Sampling for the crop complex year 2011-14        NaN        NaN
# 2                                         NaN        NaN        NaN
# 3                               Tehsil (Nos.)     Tehsil   District
# 4                                           1     Chamba     Chamba
#
#         Unnamed: 5
# 0              NaN
# 1              NaN
# 2              NaN
# 3  Cluster Village
# 4           1.Nanu

# %%
data_HP = data_HP.iloc[3:].reset_index(drop=True)

data_HP.columns = data_HP.iloc[0]

data_HP = data_HP.drop(0).reset_index(drop=True)

data_HP['State Name'] = 'Himachal Pradesh'
data_HP['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_HP.head()
# Out:
# 0 Zone Tehsil (Nos.)  Tehsil District Cluster Village        State Name  \
# 0  NaN             1  Chamba   Chamba          1.Nanu  Himachal Pradesh
# 1  NaN           NaN     NaN      NaN         2.Sarol  Himachal Pradesh
# 2    I             2  Churah   Chamba         1.Gwari  Himachal Pradesh
# 3  NaN           NaN     NaN      NaN       2.Salahan  Himachal Pradesh
# 4  NaN           NaN     NaN      NaN        3.Kuther  Himachal Pradesh
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %%
data_HP = data_HP.ffill()

# %%
data_HP.head()
# Out:
# 0 Zone Tehsil (Nos.)  Tehsil District Cluster Village        State Name  \
# 0  NaN             1  Chamba   Chamba          1.Nanu  Himachal Pradesh
# 1  NaN             1  Chamba   Chamba         2.Sarol  Himachal Pradesh
# 2    I             2  Churah   Chamba         1.Gwari  Himachal Pradesh
# 3    I             2  Churah   Chamba       2.Salahan  Himachal Pradesh
# 4    I             2  Churah   Chamba        3.Kuther  Himachal Pradesh
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %%
index_to_drop = [38, 83]
data_HP = data_HP.drop(index_to_drop)

# %%
data_HP.head()
# Out:
# 0 Zone Tehsil (Nos.)  Tehsil District Cluster Village        State Name  \
# 0  NaN             1  Chamba   Chamba          1.Nanu  Himachal Pradesh
# 1  NaN             1  Chamba   Chamba         2.Sarol  Himachal Pradesh
# 2    I             2  Churah   Chamba         1.Gwari  Himachal Pradesh
# 3    I             2  Churah   Chamba       2.Salahan  Himachal Pradesh
# 4    I             2  Churah   Chamba        3.Kuther  Himachal Pradesh
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',  'Village', 'State Name', 'Year']

data_HP.columns = new_column_names

# %%
data_HP[['District Name', 'Tehsil Code']] = data_HP[['Tehsil Code', 'District Name']]

# %%
data_HP.head()
# Out:
#   Zone No District Name Tehsil Code Tehsil Name      Village  \
# 0     NaN        Chamba           1      Chamba       1.Nanu
# 1     NaN        Chamba           1      Chamba      2.Sarol
# 2       I        Churah           2      Chamba      1.Gwari
# 3       I        Churah           2      Chamba    2.Salahan
# 4       I        Churah           2      Chamba     3.Kuther
#
#          State Name       Year
# 0  Himachal Pradesh  2011-2014
# 1  Himachal Pradesh  2011-2014
# 2  Himachal Pradesh  2011-2014
# 3  Himachal Pradesh  2011-2014
# 4  Himachal Pradesh  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']

data_HP.columns = new_column_names

# %%
data_HP.head()
# Out:
#   Zone No District Name Tehsil Code Tehsil Name Village Name  \
# 0     NaN        Chamba           1      Chamba       1.Nanu
# 1     NaN        Chamba           1      Chamba      2.Sarol
# 2       I        Churah           2      Chamba      1.Gwari
# 3       I        Churah           2      Chamba    2.Salahan
# 4       I        Churah           2      Chamba     3.Kuther
#
#          State Name       Year
# 0  Himachal Pradesh  2011-2014
# 1  Himachal Pradesh  2011-2014
# 2  Himachal Pradesh  2011-2014
# 3  Himachal Pradesh  2011-2014
# 4  Himachal Pradesh  2011-2014

# %% [markdown]
# ### 7. Haryana

# %%
data_Haryana = pd.read_excel('P2011-14.xls', sheet_name=5)

# %%
data_Haryana.head()
# Out:
#   Format-II - Detail for Zone, District, Tehsil, Village Selected for the Block Period   \
# 0  2011-2014 under Cost of Cultivation Scheme (Ha...
# 1                                          Zone No.
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#       Unnamed: 1    Unnamed: 2    Unnamed: 3    Unnamed: 4
# 0            NaN           NaN           NaN           NaN
# 1  District Name  Tehsil Code   Tehsil Name   Village Name
# 2       Bhiwani              1      Bhiwani       Maneharu
# 3       Bhiwani              2       Siwani       Dhulkot
# 4         Rewari             3       Rewari        Hasaka

# %%
data_Haryana = data_Haryana.iloc[1:].reset_index(drop=True)

data_Haryana.columns = data_Haryana.iloc[0]

data_Haryana = data_Haryana.drop(0).reset_index(drop=True)

data_Haryana['State Name'] = 'Haryana'
data_Haryana['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_Haryana.head()
# Out:
# 0 Zone No.  District Name Tehsil Code     Tehsil Name  Village Name  \
# 0         1      Bhiwani             1        Bhiwani      Maneharu
# 1         1      Bhiwani             2         Siwani      Dhulkot
# 2         1        Rewari            3         Rewari       Hasaka
# 3         1        Rewari            4           Bawal       Tihara
# 4         1      Bhiwani             5  Charkhi Dadri     Fatehgarh
#
# 0 State Name       Year
# 0    Haryana  2011-2014
# 1    Haryana  2011-2014
# 2    Haryana  2011-2014
# 3    Haryana  2011-2014
# 4    Haryana  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']

data_Haryana.columns = new_column_names

# %% [markdown]
# ### 8. Karnataka

# %%
data_Karnataka = pd.read_excel('P2011-14.xls', sheet_name=6)

# %%
data_Karnataka.head()
# Out:
#                        Zone Name & Number  District Name  Tehsil Code  \
# 0  I-North Eastern Transitinal Zone (NETZ)         Bidar            1
# 1                                      NaN           NaN            2
# 2                                      NaN      Gulbarga            3
# 3        II- North Eastern Dry Zone (NEDZ)      Yadagiri            4
# 4                                      NaN           NaN            5
#
#     Tehsil Name Village Name
# 0         Aurad  Rakshal (B)
# 1  Basavakalyan        Rajoi
# 2         Aland    Rudrawadi
# 3      shahapur  Doranahalli
# 4      Shorapur  Kavadimatti

# %%
data_Karnataka = data_Karnataka.ffill()

# %%
data_Karnataka.head()
# Out:
#                        Zone Name & Number  District Name  Tehsil Code  \
# 0  I-North Eastern Transitinal Zone (NETZ)         Bidar            1
# 1  I-North Eastern Transitinal Zone (NETZ)         Bidar            2
# 2  I-North Eastern Transitinal Zone (NETZ)      Gulbarga            3
# 3        II- North Eastern Dry Zone (NEDZ)      Yadagiri            4
# 4        II- North Eastern Dry Zone (NEDZ)      Yadagiri            5
#
#     Tehsil Name Village Name
# 0         Aurad  Rakshal (B)
# 1  Basavakalyan        Rajoi
# 2         Aland    Rudrawadi
# 3      shahapur  Doranahalli
# 4      Shorapur  Kavadimatti

# %%
data_Karnataka['State Name'] = 'Karnataka'
data_Karnataka['Year'] = '2011-2014'

# %%
data_Karnataka.columns
# Out:
# Index(['Zone Name & Number ', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object')

# %%
data_Karnataka['Zone No'] = data_Karnataka['Zone Name & Number '].str.extract(r'^(I{1,3}|IV|V{1,3})')

# Drop the original "Zone Name and Number" column
data_Karnataka = data_Karnataka.drop(columns=['Zone Name & Number '])

# %%
data_Karnataka.head()
# Out:
#   District Name  Tehsil Code   Tehsil Name Village Name State Name       Year  \
# 0         Bidar            1         Aurad  Rakshal (B)  Karnataka  2011-2014
# 1         Bidar            2  Basavakalyan        Rajoi  Karnataka  2011-2014
# 2      Gulbarga            3         Aland    Rudrawadi  Karnataka  2011-2014
# 3      Yadagiri            4      shahapur  Doranahalli  Karnataka  2011-2014
# 4      Yadagiri            5      Shorapur  Kavadimatti  Karnataka  2011-2014
#
#   Zone No
# 0       I
# 1       I
# 2       I
# 3      II
# 4      II

# %%
desired_order = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']
data_Karnataka = data_Karnataka[desired_order]

# %% [markdown]
# ### 9. Kerala

# %%
data_Kerala = pd.read_excel('P2011-14.xls', sheet_name=7)

# %%
data_Kerala.head()
# Out:
#                                           Unnamed: 0  \
# 0                                                NaN
# 1  Details of selected villages of Study on Cost ...
# 2                                                NaN
# 3                                                NaN
# 4  For the purpose of the Study on Cost of Cultiv...
#
#                       Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0                            NaN        NaN        NaN        NaN
# 1                            NaN        NaN        NaN        NaN
# 2  for the Block  period 2011-14        NaN        NaN        NaN
# 3                            NaN        NaN        NaN        NaN
# 4                            NaN        NaN        NaN        NaN

# %%
data_Kerala = data_Kerala.iloc[8:].reset_index(drop=True)

data_Kerala.columns = data_Kerala.iloc[0]

data_Kerala = data_Kerala.drop(0).reset_index(drop=True)

data_Kerala['State Name'] = 'Kerala'
data_Kerala['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_Kerala.head()
# Out:
# 0 Zone No       District Name Tehsil Code    Tehsil Name  Village Name  \
# 0       1           Alappuzha           1      Kuttanad        Kavalam
# 1       1           Alappuzha           2      Kuttanad   Neelampeerur
# 2       1            Kottayam           3         Vaikom       Kallara
# 3       1            Thrissur           4      Chavakkad    Venkidangu
# 4       2  Thiruvananthapuram           5  Neyyattinkara      Kulathur
#
# 0 State Name       Year
# 0     Kerala  2011-2014
# 1     Kerala  2011-2014
# 2     Kerala  2011-2014
# 3     Kerala  2011-2014
# 4     Kerala  2011-2014

# %% [markdown]
# ### 10. Maharastra

# %%
data_MH = pd.read_excel('P2011-14.xls', sheet_name=8)

# %%
data_MH.head()
# Out:
#   Comprehensive Scheme, Department of Agril Economics,     Unnamed: 1  \
# 0       MPKV, Rahuri, Dist- Ahmednagar.(Maharashtra)              NaN
# 1                               Block Period 2011-14              NaN
# 2                                            Zone No    District Name
# 3                                                  I        Ratnagiri
# 4                                                III            Thane
#
#     Unnamed: 2   Unnamed: 3    Unnamed: 4
# 0          NaN          NaN           NaN
# 1          NaN          NaN           NaN
# 2  Tehsil Code  Tehsil Name  Village Name
# 3            1      Chiplun      Shirgaon
# 4            2      Mokhada     Morchondi

# %%
data_MH = data_MH.iloc[2:].reset_index(drop=True)

data_MH.columns = data_MH.iloc[0]

data_MH = data_MH.drop(0).reset_index(drop=True)

data_MH['State Name'] = 'Maharastra'
data_MH['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_MH.head()
# Out:
# 0 Zone No District Name Tehsil Code Tehsil Name     Village Name  State Name  \
# 0       I     Ratnagiri           1     Chiplun         Shirgaon  Maharastra
# 1     III         Thane           2     Mokhada        Morchondi  Maharastra
# 2      IV        Satara           3       Patan            Nisre  Maharastra
# 3      IV          Pune           4        Khed  Shel Pimpalgaon  Maharastra
# 4       V          Pune           5      Junnar      Shiroli Bk.  Maharastra
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']

data_Haryana.columns = new_column_names

# %% [markdown]
# ### 11. Madhya Pradesh

# %%
data_MP = pd.read_excel('P2011-14.xls', sheet_name=9)

# %%
data_MP.head(9)
# Out:
#                                           Unnamed: 0     Unnamed: 1  \
# 0               DEPARTMENT OF AGRICULTURAL ECONOMICS            NaN
# 1                 AND FARM MANAGEMENT JNKVV JABALPUR            NaN
# 2                                                NaN            NaN
# 3                    CROP COMPLEX YEAR – (2011-2014)            NaN
# 4                                                NaN            NaN
# 5                   MADHYA PRADESH (STATE CODE - 09)            NaN
# 6                                                NaN            NaN
# 7  LIST OF SELECTED DISTRICT, TEHSIL AND  VILLAGES              NaN
# 8                                            Zone No  District Name
#
#     Unnamed: 2   Unnamed: 3    Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0          NaN          NaN           NaN        NaN        NaN
# 1          NaN          NaN           NaN        NaN        NaN
# 2          NaN          NaN           NaN        NaN        NaN
# 3          NaN          NaN           NaN        NaN        NaN
# 4          NaN          NaN           NaN        NaN        NaN
# 5          NaN          NaN           NaN        NaN        NaN
# 6          NaN          NaN           NaN        NaN        NaN
# 7          NaN          NaN           NaN        NaN        NaN
# 8  Tehsil Code  Tehsil Name  Village Name        NaN        NaN

# %%
data_MP = data_MP.iloc[8:].reset_index(drop=True)

data_MP.columns = data_MP.iloc[0]

data_MP = data_MP.drop(0).reset_index(drop=True)

data_MP['State Name'] = 'Madhya Pradesh'
data_MP['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_MP.head()
# Out:
# 0 Zone No District Name Tehsil Code       Tehsil Name Village Name  NaN  NaN  \
# 0       1         Bhind           1             Bhind      Pidoura  NaN  NaN
# 1       1      Maureina           2  Jora (Pahargarh)      Chhaira  NaN  NaN
# 2       2      Shivpuri           3          Badarwar      Sumeila  NaN  NaN
# 3       2         Datia           4             Datia        Uprai  NaN  NaN
# 4       2          Guna           5        Raghavgarh        Aavan  NaN  NaN
#
# 0      State Name       Year
# 0  Madhya Pradesh  2011-2014
# 1  Madhya Pradesh  2011-2014
# 2  Madhya Pradesh  2011-2014
# 3  Madhya Pradesh  2011-2014
# 4  Madhya Pradesh  2011-2014

# %%
data_MP.head()
# Out:
# 0 Zone No District Name Tehsil Code       Tehsil Name Village Name  NaN  NaN  \
# 0       1         Bhind           1             Bhind      Pidoura  NaN  NaN
# 1       1      Maureina           2  Jora (Pahargarh)      Chhaira  NaN  NaN
# 2       2      Shivpuri           3          Badarwar      Sumeila  NaN  NaN
# 3       2         Datia           4             Datia        Uprai  NaN  NaN
# 4       2          Guna           5        Raghavgarh        Aavan  NaN  NaN
#
# 0      State Name       Year
# 0  Madhya Pradesh  2011-2014
# 1  Madhya Pradesh  2011-2014
# 2  Madhya Pradesh  2011-2014
# 3  Madhya Pradesh  2011-2014
# 4  Madhya Pradesh  2011-2014

# %%
data_MP.columns = data_MP.columns.fillna('to_drop')
data_MP.drop('to_drop', axis = 1, inplace = True)

# %%
data_MP.head()
# Out:
# 0 Zone No District Name Tehsil Code       Tehsil Name Village Name  \
# 0       1         Bhind           1             Bhind      Pidoura
# 1       1      Maureina           2  Jora (Pahargarh)      Chhaira
# 2       2      Shivpuri           3          Badarwar      Sumeila
# 3       2         Datia           4             Datia        Uprai
# 4       2          Guna           5        Raghavgarh        Aavan
#
# 0      State Name       Year
# 0  Madhya Pradesh  2011-2014
# 1  Madhya Pradesh  2011-2014
# 2  Madhya Pradesh  2011-2014
# 3  Madhya Pradesh  2011-2014
# 4  Madhya Pradesh  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']

data_MP.columns = new_column_names

# %%
data_MP = data_MP.dropna()

# %%
data_MP.head()
# Out:
#   Zone No District Name Tehsil Code       Tehsil Name Village Name  \
# 0       1         Bhind           1             Bhind      Pidoura
# 1       1      Maureina           2  Jora (Pahargarh)      Chhaira
# 2       2      Shivpuri           3          Badarwar      Sumeila
# 3       2         Datia           4             Datia        Uprai
# 4       2          Guna           5        Raghavgarh        Aavan
#
#        State Name       Year
# 0  Madhya Pradesh  2011-2014
# 1  Madhya Pradesh  2011-2014
# 2  Madhya Pradesh  2011-2014
# 3  Madhya Pradesh  2011-2014
# 4  Madhya Pradesh  2011-2014

# %% [markdown]
# ### 12. Chhattisgarh

# %%
data_Chh = pd.read_excel('P2011-14.xls', sheet_name=10)

# %%
data_Chh.head()
# Out:
#              COST OF CULTIVATION SCHEME Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0  DEPARTMENT OF AGRICULTURAL ECONOMICS        NaN        NaN        NaN
# 1    AND FARM MANAGEMENT JNKVV JABALPUR        NaN        NaN        NaN
# 2       CROP COMPLEX YEAR – (2011-2014)        NaN        NaN        NaN
# 3                                   NaN        NaN        NaN        NaN
# 4        CHHATTISGARH (STATE CODE - 19)        NaN        NaN        NaN
#
#   Unnamed: 4
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
data_Chh = data_Chh.iloc[7:].reset_index(drop=True)

data_Chh.columns = data_Chh.iloc[0]

data_Chh = data_Chh.drop(0).reset_index(drop=True)

data_Chh['State Name'] = 'Chhattisgarh'
data_Chh['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_Chh.head()
# Out:
# 0 Zone No District Name Tehsil Code Tehsil Name Village Name    State Name  \
# 0       1       Raigarh           1   Gharghora        Teram  Chhattisgarh
# 1       1         Korba           2       Korba     Semipali  Chhattisgarh
# 2       1      Bilaspur           3     Mustari         Itva  Chhattisgarh
# 3       1      Janjgeer           4       Dabra    Devarghat  Chhattisgarh
# 4       1       Jashpur           5  Pathalgaon      Shivpur  Chhattisgarh
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %% [markdown]
# ### 13. Odisha

# %%
data_Odd = pd.read_excel('P2011-14.xls', sheet_name=11)

# %%
data_Odd.head()
# Out:
#     Information Of Odisha to be Posted on the Web-site of the DES  \
# 0                                                ...
# 1                                            Zone No
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#       Unnamed: 1   Unnamed: 2   Unnamed: 3    Unnamed: 4
# 0            NaN          NaN          NaN           NaN
# 1  District Name  Tehsil Code  Tehsil Name  Village Name
# 2       Balasore            1     Jaleswar       Bartana
# 3       Balasore            2     Balasore       Chhanua
# 4        Bhadrak            3    Chandbali      Nandapur

# %%
data_Odd = data_Odd.iloc[1:].reset_index(drop=True)

data_Odd.columns = data_Odd.iloc[0]

data_Odd = data_Odd.drop(0).reset_index(drop=True)

data_Odd['State Name'] = 'Odisha'
data_Odd['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_Odd.head()
# Out:
# 0 Zone No District Name Tehsil Code     Tehsil Name   Village Name State Name  \
# 0       1      Balasore           1        Jaleswar        Bartana     Odisha
# 1       1      Balasore           2        Balasore        Chhanua     Odisha
# 2       1       Bhadrak           3       Chandbali       Nandapur     Odisha
# 3       1       Cuttack           4  Nischintakoili         Patpur     Odisha
# 4       1       Cuttack           5         Salepur  Satyabhamapur     Odisha
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %% [markdown]
# ### 14. Punjab

# %%
data_Pb = pd.read_excel('P2011-14.xls', sheet_name=12)

# %%
data_Pb.head()
# Out:
#     Unnamed: 0       Unnamed: 1       Unnamed: 2  \
# 0  Information    for the block  period  2011-14
# 1          NaN              NaN              NaN
# 2     Zone  No    District Name          Tehsil
# 3          NaN              NaN             Code
# 4            I        Gurdaspur                1
#
#                                  Unnamed: 3    Unnamed: 4
# 0  Punjab Agricultural University, Ludhiana           NaN
# 1                                       NaN           NaN
# 2                                   Tehsil   Village Name
# 3                                      Name           NaN
# 4                                 Gurdaspur       Shaikha

# %%
data_Pb = data_Pb.iloc[2:].reset_index(drop=True)

data_Pb.columns = data_Pb.iloc[0]

data_Pb = data_Pb.drop(0).reset_index(drop=True)

data_Pb['State Name'] = 'Punjab'
data_Pb['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_Pb.head()
# Out:
# 0 Zone  No District Name Tehsil       Tehsil      Village Name State Name  \
# 0      NaN           NaN    Code         Name              NaN     Punjab
# 1        I     Gurdaspur       1    Gurdaspur          Shaikha     Punjab
# 2      NaN     Gurdaspur       2       Batala            Bojha     Punjab
# 3      NaN      Amrtisar       3  Amritsar-II  Pandori Wraich      Punjab
# 4      NaN     Tarntaean       4        Patti           Kairon     Punjab
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %%
data_Pb = data_Pb.ffill()

# %%
data_Pb.head()
# Out:
# 0 Zone  No District Name Tehsil       Tehsil      Village Name State Name  \
# 0      NaN           NaN    Code         Name              NaN     Punjab
# 1        I     Gurdaspur       1    Gurdaspur          Shaikha     Punjab
# 2        I     Gurdaspur       2       Batala            Bojha     Punjab
# 3        I      Amrtisar       3  Amritsar-II  Pandori Wraich      Punjab
# 4        I     Tarntaean       4        Patti           Kairon     Punjab
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']

data_Pb.columns = new_column_names

# %% [markdown]
# ### 15. Rajasthan

# %%
data_RJ = pd.read_excel('P2011-14.xls', sheet_name=13)

# %%
data_RJ.head()
# Out:
#                   Cost of Cultivation Studies     Unnamed: 1   Unnamed: 2  \
# 0                              MPUAT, Udaipur            NaN          NaN
# 1                                         NaN            NaN          NaN
# 2   Summary Data for the block Period 2011-14            NaN          NaN
# 3                                         NaN            NaN          NaN
# 4                                    Zone No.  District Name  Tehsil Code
#
#     Unnamed: 3    Unnamed: 4
# 0          NaN           NaN
# 1          NaN           NaN
# 2          NaN           NaN
# 3          NaN           NaN
# 4  Tehsil Name  Village Name

# %%
data_RJ = data_RJ.iloc[4:].reset_index(drop=True)

data_RJ.columns = data_RJ.iloc[0]

data_RJ = data_RJ.drop(0).reset_index(drop=True)

data_RJ['State Name'] = 'Rajasthan'
data_RJ['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_RJ.head()
# Out:
# 0 Zone No. District Name Tehsil Code Tehsil Name  Village Name State Name  \
# 0        I           NaN         NaN         NaN           NaN  Rajasthan
# 1                Jodhpur           1    Shergarh           Sai  Rajasthan
# 2      NaN       Jodhpur           2    Shergarh  Kherja Tibna  Rajasthan
# 3      NaN        Barmer           3      Barmer         Jasai  Rajasthan
# 4      NaN       Jodhpur           4     Phalodi     Shekhasar  Rajasthan
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %%
data_RJ = data_RJ.ffill()

# %%
data_RJ.head()
# Out:
# 0 Zone No. District Name  Tehsil Code Tehsil Name  Village Name State Name  \
# 0        I           NaN          NaN         NaN           NaN  Rajasthan
# 1                Jodhpur          1.0    Shergarh           Sai  Rajasthan
# 2                Jodhpur          2.0    Shergarh  Kherja Tibna  Rajasthan
# 3                 Barmer          3.0      Barmer         Jasai  Rajasthan
# 4                Jodhpur          4.0     Phalodi     Shekhasar  Rajasthan
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %%
data_RJ.loc[1:11, 'Zone No.'] = 'I'

# %%
data_RJ.head()
# Out:
# 0 Zone No. District Name  Tehsil Code Tehsil Name  Village Name State Name  \
# 0        I           NaN          NaN         NaN           NaN  Rajasthan
# 1        I       Jodhpur          1.0    Shergarh           Sai  Rajasthan
# 2        I       Jodhpur          2.0    Shergarh  Kherja Tibna  Rajasthan
# 3        I        Barmer          3.0      Barmer         Jasai  Rajasthan
# 4        I       Jodhpur          4.0     Phalodi     Shekhasar  Rajasthan
#
# 0       Year
# 0  2011-2014
# 1  2011-2014
# 2  2011-2014
# 3  2011-2014
# 4  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']

data_RJ.columns = new_column_names

# %% [markdown]
# ### 16. Tamil Nadu

# %%
data_TN = pd.read_excel('P2011-14.xls', sheet_name=14)

# %%
data_TN.head()
# Out:
#                                           Unnamed: 0     Unnamed: 1  \
# 0         COMPREHENSIVE SCHEME FOR STUDYING THE C...            NaN
# 1  Details of Zone, District, Tehsil, Villages Se...            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                           ZONE No.  DISTRICT NAME
#
#     Unnamed: 2   Unnamed: 3    Unnamed: 4
# 0          NaN          NaN           NaN
# 1          NaN          NaN           NaN
# 2          NaN          NaN           NaN
# 3          NaN          NaN           NaN
# 4  TEHSIL CODE  TEHSIL NAME  VILLAGE NAME

# %%
data_TN = data_TN.iloc[4:].reset_index(drop=True)

data_TN.columns = data_TN.iloc[0]

data_TN = data_TN.drop(0).reset_index(drop=True)

data_TN['State Name'] = 'Tamil Nadu'
data_TN['Year'] = '2011-2014'

#data_AP = data_AP.dropna(axis=1, how='any')

# %%
data_TN.head()
# Out:
# 0 ZONE No. DISTRICT NAME TEHSIL CODE   TEHSIL NAME    VILLAGE NAME  \
# 0        1   THIRUVALLUR           1       PONNERI  ANUPPAMPATTU-2
# 1        1   THIRUVALLUR           2   THIRUVALLUR      VELLIYUR-1
# 2        1  KANCHEEPURAM           3  KANCHEEPURAM         PURISAI
# 3        2       VELLORE           4    GUDIYATHAM       KALLAPADI
# 4        2       VELLORE           5       VELLORE         THELLUR
#
# 0  State Name       Year
# 0  Tamil Nadu  2011-2014
# 1  Tamil Nadu  2011-2014
# 2  Tamil Nadu  2011-2014
# 3  Tamil Nadu  2011-2014
# 4  Tamil Nadu  2011-2014

# %%
index_to_drop = [25, 46]
data_TN = data_TN.drop(index_to_drop)

# %%
data_TN.head()
# Out:
# 0 ZONE No. DISTRICT NAME TEHSIL CODE   TEHSIL NAME    VILLAGE NAME  \
# 0        1   THIRUVALLUR           1       PONNERI  ANUPPAMPATTU-2
# 1        1   THIRUVALLUR           2   THIRUVALLUR      VELLIYUR-1
# 2        1  KANCHEEPURAM           3  KANCHEEPURAM         PURISAI
# 3        2       VELLORE           4    GUDIYATHAM       KALLAPADI
# 4        2       VELLORE           5       VELLORE         THELLUR
#
# 0  State Name       Year
# 0  Tamil Nadu  2011-2014
# 1  Tamil Nadu  2011-2014
# 2  Tamil Nadu  2011-2014
# 3  Tamil Nadu  2011-2014
# 4  Tamil Nadu  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']

data_TN.columns = new_column_names

# %% [markdown]
# ### 17. West Bengal

# %%
data_WB = pd.read_excel('P2011-14.xls', sheet_name=15)

# %%
data_WB.head(9)
# Out:
#                                  Unnamed: 0  Unnamed: 1  \
# 0  Comprehensive Cost of Cultivation Scheme         NaN
# 1               R.B.S.College,Bichpuri,Agra         NaN
# 2                                       NaN         NaN
# 3                                       NaN         NaN
# 4                                       NaN         NaN
# 5                                       NaN         NaN
# 6                                       NaN         NaN
# 7                                       NaN         NaN
# 8                                       NaN         NaN
#
#                                           Unnamed: 2    Unnamed: 3 Unnamed: 4  \
# 0                                                NaN           NaN        NaN
# 1                                                NaN           NaN        NaN
# 2                                                NaN           NaN        NaN
# 3  Name of Districts,Selected Tehsils and Village...           NaN        NaN
# 4                                               Zone      District     Tehsil
# 5                                                no.          Name       Code
# 6                                                  1  Rudra Prayag          1
# 7                                                  2     U.S.Nagar          2
# 8                                                  2     U.S.Nagar          3
#
#      Unnamed: 5         Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0           NaN                NaN        NaN        NaN
# 1           NaN                NaN        NaN        NaN
# 2           NaN                NaN        NaN        NaN
# 3           NaN                NaN        NaN        NaN
# 4        Tehsil  Selected Villages        NaN        NaN
# 5          Name            Nucleus      South      Third
# 6  Rudra Prayag            Nagrasu     Mabada        NaN
# 7     Sitarganj            Darhaha    Malpuri        NaN
# 8        Jaspur          Kishanpur        NaN        NaN

# %%
data_WB = data_WB.iloc[4:].reset_index(drop=True)

data_WB.columns = data_WB.iloc[0]

data_WB = data_WB.drop(0).reset_index(drop=True)

data_WB['State Name'] = 'West Bengal'
data_WB['Year'] = '2011-2014'

# %%
data_WB.head(7)
# Out:
# 0  NaN NaN Zone      District Tehsil        Tehsil   Selected Villages  \
# 0  NaN NaN  no.          Name   Code          Name             Nucleus
# 1  NaN NaN    1  Rudra Prayag      1  Rudra Prayag             Nagrasu
# 2  NaN NaN    2     U.S.Nagar      2     Sitarganj             Darhaha
# 3  NaN NaN    2     U.S.Nagar      3        Jaspur           Kishanpur
# 4  NaN NaN    3      Haridwar      4      Haridwar             Bhogpur
# 5  NaN NaN    2     Baharaich      5       Nanpara  Jagannathpur-purey
# 6  NaN NaN    2         Khiri      6        Paliya            Badagaon
#
# 0      NaN    NaN   State Name       Year
# 0    South  Third  West Bengal  2011-2014
# 1   Mabada    NaN  West Bengal  2011-2014
# 2  Malpuri    NaN  West Bengal  2011-2014
# 3      NaN    NaN  West Bengal  2011-2014
# 4      NaN    NaN  West Bengal  2011-2014
# 5      NaN    NaN  West Bengal  2011-2014
# 6      NaN    NaN  West Bengal  2011-2014

# %%
data_WB = data_WB.iloc[:, 2:]

# %%
data_WB.head(5)
# Out:
# 0 Zone      District Tehsil        Tehsil Selected Villages      NaN    NaN  \
# 0  no.          Name   Code          Name           Nucleus    South  Third
# 1    1  Rudra Prayag      1  Rudra Prayag           Nagrasu   Mabada    NaN
# 2    2     U.S.Nagar      2     Sitarganj           Darhaha  Malpuri    NaN
# 3    2     U.S.Nagar      3        Jaspur         Kishanpur      NaN    NaN
# 4    3      Haridwar      4      Haridwar           Bhogpur      NaN    NaN
#
# 0   State Name       Year
# 0  West Bengal  2011-2014
# 1  West Bengal  2011-2014
# 2  West Bengal  2011-2014
# 3  West Bengal  2011-2014
# 4  West Bengal  2011-2014

# %%
data_WB = data_WB.drop(index=0)

# %%
data_WB.head()
# Out:
# 0 Zone      District Tehsil        Tehsil   Selected Villages      NaN  NaN  \
# 1    1  Rudra Prayag      1  Rudra Prayag             Nagrasu   Mabada  NaN
# 2    2     U.S.Nagar      2     Sitarganj             Darhaha  Malpuri  NaN
# 3    2     U.S.Nagar      3        Jaspur           Kishanpur      NaN  NaN
# 4    3      Haridwar      4      Haridwar             Bhogpur      NaN  NaN
# 5    2     Baharaich      5       Nanpara  Jagannathpur-purey      NaN  NaN
#
# 0   State Name       Year
# 1  West Bengal  2011-2014
# 2  West Bengal  2011-2014
# 3  West Bengal  2011-2014
# 4  West Bengal  2011-2014
# 5  West Bengal  2011-2014

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Selected Villages', 'Village II', 'Village III', 
                    'State Name', 'Year']

data_WB.columns = new_column_names

# %%
data_WB.head()
# Out:
#   Zone No District Name Tehsil Code   Tehsil Name   Selected Villages  \
# 1       1  Rudra Prayag           1  Rudra Prayag             Nagrasu
# 2       2     U.S.Nagar           2     Sitarganj             Darhaha
# 3       2     U.S.Nagar           3        Jaspur           Kishanpur
# 4       3      Haridwar           4      Haridwar             Bhogpur
# 5       2     Baharaich           5       Nanpara  Jagannathpur-purey
#
#   Village II Village III   State Name       Year
# 1     Mabada         NaN  West Bengal  2011-2014
# 2    Malpuri         NaN  West Bengal  2011-2014
# 3        NaN         NaN  West Bengal  2011-2014
# 4        NaN         NaN  West Bengal  2011-2014
# 5        NaN         NaN  West Bengal  2011-2014

# %%
df_melted = data_WB.melt(
    id_vars=['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'State Name', 'Year'],
    value_vars=['Selected Villages', 'Village II', 'Village III'],
    var_name='Village Type',
    value_name='Village Name'
)

df_melted = df_melted.dropna(subset=['Village Name'])

df_melted = df_melted.drop(columns=['Village Type'])

df_melted = df_melted.reset_index(drop=True)

# %%
df_melted.head()
# Out:
#   Zone No District Name Tehsil Code   Tehsil Name   State Name       Year  \
# 0       1  Rudra Prayag           1  Rudra Prayag  West Bengal  2011-2014
# 1       2     U.S.Nagar           2     Sitarganj  West Bengal  2011-2014
# 2       2     U.S.Nagar           3        Jaspur  West Bengal  2011-2014
# 3       3      Haridwar           4      Haridwar  West Bengal  2011-2014
# 4       2     Baharaich           5       Nanpara  West Bengal  2011-2014
#
#          Village Name
# 0             Nagrasu
# 1             Darhaha
# 2           Kishanpur
# 3             Bhogpur
# 4  Jagannathpur-purey

# %%
data_WB = df_melted[['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']]

# %%
new_column_names = ['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name', 'Village Name', 'State Name', 'Year']

data_WB.columns = new_column_names

# %% [markdown]
# ## Integerating the Dataset

# %%
data_AP.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object', name=0)

# %%
data_Assam.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object')

# %%
data_BH.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object')

# %%
data_JH.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object')

# %%
data_GJ.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object')

# %%
data_HP.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object')

# %%
data_Haryana.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object')

# %%
data_Kerala.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object', name=0)

# %%
data_Chh.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object', name=0)

# %%
data_Odd.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object', name=0)

# %%
data_Pb.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object')

# %%
data_RJ.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object')

# %%
data_TN.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object')

# %%
data_WB.columns
# Out:
# Index(['Zone No', 'District Name', 'Tehsil Code', 'Tehsil Name',
#        'Village Name', 'State Name', 'Year'],
#       dtype='object')

# %%
dataframes = [data_AP, data_Assam, data_BH, data_JH, data_GJ, data_HP, data_Haryana, data_Kerala, data_Chh, data_Odd, 
              data_Pb, data_RJ, data_TN, data_WB, data_MP, data_Karnataka, data_MH]

merged_df = pd.concat(dataframes, ignore_index=True)

# %%
merged_df.head()
# Out:
#    Zone No  District Name Tehsil Code     Tehsil Name   Village Name  \
# 0  Zone -I     Srikakulam           1   Vajrapukothur  Patha Tekkali
# 1  Zone -I     Srikakulam           2      Amdalavasa           Dusi
# 2  Zone -I  Vizianagaram.           3      Bondapalli       B.Rajeru
# 3  Zone -I  Vishakapatnam           4  Makavara Palem      Byyavaram
# 4  Zone-II  East Godavari           5      Samalkota          J.Peta
#
#        State Name       Year
# 0  Andhra Pradesh  2011-2014
# 1  Andhra Pradesh  2011-2014
# 2  Andhra Pradesh  2011-2014
# 3  Andhra Pradesh  2011-2014
# 4  Andhra Pradesh  2011-2014

# %%
merged_df.head()
# Out:
#    Zone No  District Name Tehsil Code     Tehsil Name   Village Name  \
# 0  Zone -I     Srikakulam           1   Vajrapukothur  Patha Tekkali
# 1  Zone -I     Srikakulam           2      Amdalavasa           Dusi
# 2  Zone -I  Vizianagaram.           3      Bondapalli       B.Rajeru
# 3  Zone -I  Vishakapatnam           4  Makavara Palem      Byyavaram
# 4  Zone-II  East Godavari           5      Samalkota          J.Peta
#
#        State Name       Year
# 0  Andhra Pradesh  2011-2014
# 1  Andhra Pradesh  2011-2014
# 2  Andhra Pradesh  2011-2014
# 3  Andhra Pradesh  2011-2014
# 4  Andhra Pradesh  2011-2014

# %%
merged_df['State Name'].value_counts()
# Out:
# Assam               116
# Himachal Pradesh    101
# West Bengal          84
# Rajasthan            70
# Maharastra           62
# Tamil Nadu           60
# Andhra Pradesh       60
# Gujarat              53
# Odisha               45
# Madhya Pradesh       45
# Karnataka            45
# Bihar                44
# Punjab               31
# Kerala               30
# Haryana              30
# Jharkhand            15
# Chhattisgarh         15
# Name: State Name, dtype: int64

# %%
merged_df.head()
# Out:
#    Zone No  District Name Tehsil Code     Tehsil Name   Village Name  \
# 0  Zone -I     Srikakulam           1   Vajrapukothur  Patha Tekkali
# 1  Zone -I     Srikakulam           2      Amdalavasa           Dusi
# 2  Zone -I  Vizianagaram.           3      Bondapalli       B.Rajeru
# 3  Zone -I  Vishakapatnam           4  Makavara Palem      Byyavaram
# 4  Zone-II  East Godavari           5      Samalkota          J.Peta
#
#        State Name       Year
# 0  Andhra Pradesh  2011-2014
# 1  Andhra Pradesh  2011-2014
# 2  Andhra Pradesh  2011-2014
# 3  Andhra Pradesh  2011-2014
# 4  Andhra Pradesh  2011-2014

# %%
merged_df = merged_df.dropna(subset=['Village Name'])

# %%
merged_df
# Out:
#       Zone No       District Name  Tehsil Code           Tehsil Name  \
# 0     Zone -I          Srikakulam            1         Vajrapukothur
# 1     Zone -I          Srikakulam            2            Amdalavasa
# 2     Zone -I       Vizianagaram.            3            Bondapalli
# 3     Zone -I       Vishakapatnam            4        Makavara Palem
# 4     Zone-II       East Godavari            5            Samalkota
# 5     Zone-II       East Godavari            6             Biccavolu
# 6     Zone-II       East Godavari            7              Kajuluru
# 7     Zone-II       East Godavari            8                Razole
# 8     Zone-II       East Godavari            9           Katrenikona
# 9     Zone-II       West Godavari           10             Bhimadole
# 10    Zone-II       West Godavari           11            Denuduluru
# 11    Zone-II       West Godavari           12             Pentapudu
# 12    Zone-II       West Godavari           13          Veeravasaram
# 13    Zone-II             Krishna           14          Pedaparupudi
# 14    Zone-II             Krishna           15             Kankipadu
# 15    Zone-II              Guntur           16              Tsunduru
# 16    Zone-II              Guntur           17             Nakirekal
# 17    Zone-II              Guntur           18             Kollipara
# 18    Zone-II              Guntur           19            Pedakakani
# 19    Zone-II            Prakasam           20                 Pamur
# 20    Zone-II             Nellore           21       Thotapalligudur
# 21   Zone-III            Chittoor           22             Pitchatur
# 22   Zone-III            Chittoor           23         Narayanavanam
# 23   Zone-III            Chittoor           24             Palamaner
# 24   Zone-III            Chittoor           25               Irala .
# 25   Zone-III            Chittoor           26          Ramasumudram
# 26   Zone-III              Kadapa           27            Sundupalli
# 27   Zone-III              Kadapa           28               Kajipet
# 28   Zone-III              Kadapa           29              Vempalli
# 29   Zone-III              Kadapa           30            Galliveedu
# 30   Zone-III          Ananthapur           31             Beluguppa
# 31   Zone-III          Ananthapur           32          Kothacheruvu
# 32   Zone-III             Kurnool           33               Midthur
# 33   Zone-III             Kurnool           34            Nandavaram
# 34   Zone-III             Kurnool           35          Kolimigundla
# 35    Zone-IV       Mahaboobnagar           36        Talakondapalli
# 36    Zone-IV       Mahaboobnagar           37             Jadcherla
# 37    Zone-IV       Mahaboobnagar           38               Manopad
# 38    Zone-IV         Ranga Reddy           39              Mominpet
# 39    Zone-IV         Ranga Reddy           40          Shankarpalli
# 40    Zone-IV         Ranga Reddy           41                Shabad
# 41    Zone-IV             Khammam           42            Yerrupalem
# 414         3             Ambala            26            Naraingarh
# 415         3             Karnal            27             Nilokheri
# 416         3         Kurukshetra           28                Pehowa
# 417         3           Faridabad           29            Faridabad
# 418         3         Kurukshetra           30              Thanesar
# 419         1           Alappuzha            1             Kuttanad
# 420         1           Alappuzha            2             Kuttanad
# 421         1            Kottayam            3                Vaikom
# 422         1            Thrissur            4             Chavakkad
# 423         2  Thiruvananthapuram            5         Neyyattinkara
# 424         2  Thiruvananthapuram            6           Chirayinkil
# 425         2              Kollam            7                Kollam
# 426         2              Kollam            8           Kottarakara
# 427         2           Alappuzha            9           Mavelikkara
# 428         2            Kottayam           10              Kottayam
# 429         2           Ernakulam           11         Moovattupuzha
# 430         2           Ernakulam           12           Kunnathunad
# 431         2            Thrissur           13          Mukundapuram
# 432         2            Thrissur           14               Trichur
# 433         2            Thrissur           15           Thalappally
# 434         2            Palakkad           16            Ottappalam
# 435         2          Malappuram           17           Tirurangadi
# 436         2          Malappuram           18                 Ernad
# 437         2          Kozhikkode           19            Kozhikkade
# 438         2          Kozhikkode           20              Koilandy
# 439         2              Kannur           21         Thalipparampu
# 440         3              Idukki           22            Thodupuzha
# 441         3              Idukki           23          Udumpanchola
# 442         3            Palakkad           24              Palakkad
# 443         3            Palakkad           25               Alathur
# 444         3            Palakkad           26            Mannarkkad
# 445         3            Palakkad           27               Chittur
# 446         3            Palakkad           28               Chittur
# 447         3              Waynad           29       Sulthan Batheri
# 448         3           Kasaragod           30               Hosdurg
# 449         1             Raigarh            1             Gharghora
# 450         1               Korba            2                 Korba
# 451         1            Bilaspur            3               Mustari
# 452         1            Janjgeer            4                 Dabra
# 453         1             Jashpur            5            Pathalgaon
# 454         1             Sarguja            6              Udayapur
# 455         2                Durg            7               Dhamdha
# 456         2              Raipur            8                Palari
# 457         2          Mahasamund            9                Basana
# 458         2                Durg           10                 Balod
# 459         2         Rajnandgaon           11           Rajnandgaon
# 460         2            Kawardha           12             Pandariya
# 461         2              Raipur           13              Abhanpur
# 462         2         Rajnandgaon           14            Dongargarh
# 463         2            Dhamtari           15              Dhamtari
# 464         1            Balasore            1              Jaleswar
# 465         1            Balasore            2              Balasore
# 466         1             Bhadrak            3             Chandbali
# 467         1             Cuttack            4        Nischintakoili
# 468         1             Cuttack            5               Salepur
# 469         1       Jagatsinghpur            6              Balikuda
# 470         1              Jajpur            7            Dharmasala
# 471         1          Kendrapara            8            Kendrapara
# 472         1          Kendrapara            9              Derabish
# 473         1                Puri           10                Pipili
# 474         1                Puri           11            Puri Sadar
# 475         1              Khurda           12                 Tangi
# 476         1            Nayagarh           13               Nuagaon
# 477         1              Ganjam           14              Patrapur
# 478         1              Ganjam           15             Sheragada
# 479         1              Ganjam           16       Jagannathprasad
# 480         1            Gajapati           17        Paralakhemundi
# 481         2             Koraput           18              Nandapur
# 482         2          Malkangiri           19            Malkangiri
# 483         2         Nabarangpur           20           Papadahandi
# 484         2            Rayagada           21              Kashipur
# 485         2           Kalahandi           22          Bhawanipatna
# 486         2           Kalahandi           23                 Narla
# 487         2           Kalahandi           24               Kesinga
# 488         2             Nuapada           25                 Komna
